# %%
a = dict()
a["WEIGHTED SUM"]=(0.7, 0.5, 0.8)
a["SUM"]=(0.9, 0.6, 0.8)
a["AVG"]=(0.92, 0.45, 0.82)

col_first = list()
col_second = list()
first_second = list()

for key in a.keys():
    col_first.append(a[key][0])
    col_second.append(a[key][1])
    first_second.append(a[key][2])

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt


barWidth = 0.25
fig = plt.subplots(figsize =(12, 8)) 
br1 = np.arange(len(col_first)) 
br2 = [x + barWidth for x in br1] 
br3 = [x + barWidth for x in br2]

plt.bar(br1, col_first, color ='r', width = barWidth, 
        edgecolor ='grey', label ='First half') 
plt.bar(br2, col_second, color ='g', width = barWidth, 
        edgecolor ='grey', label ='Second half') 
plt.bar(br3, first_second, color ='b', width = barWidth, 
        edgecolor ='grey', label ='first second') 

plt.xlabel('Function type', fontweight ='bold', fontsize = 15) 
plt.ylabel('Similarity', fontweight ='bold', fontsize = 15) 
plt.xticks([r + barWidth for r in range(len(col_first))], 
        a.keys())

plt.legend()
plt.show()

# %%
a = dict()
a["WEIGHTED SUM"]= 17.3
a["SUM"]=15.8
a["AVG"]= 14.8

# %%
courses = list(a.keys())
values = list(a.values())
print(courses)
print(values)
fig = plt.figure(figsize = (10, 5))

# creating the bar plot
plt.bar(courses, values, color ='maroon', 
        width = 0.4)

plt.xlabel("Courses offered")
plt.ylabel("No. of students enrolled")
plt.title("Students enrolled in different courses")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 7
#       4 fig = plt.figure(figsize = (10, 5))
#       6 # creating the bar plot
# ----> 7 plt.bar(courses, values, color ='maroon',
#       8         width = 0.4)
#      10 plt.xlabel("Courses offered")
#      11 plt.ylabel("No. of students enrolled")
#
# File ~/Desktop/remeve_me/pythonProject1/.venv/lib/python3.9/site-packages/matplotlib/pyplot.py:2870, in bar(x, height, width, bottom, align, data, **kwargs)
#    2859 @_copy_docstring_and_deprecators(Axes.bar)
#    2860 def bar(
#    2861     x: float | ArrayLike,
#    (...)
#    2868     **kwargs,
#    2869 ) -> BarContainer:
# -> 2870     return gca().bar(
#    2871         x,
#    2872         height,
#    2873         width=width,
#    2874         bottom=bottom,
#    2875         align=align,
#    2876         **({"data": data} if data is not None else {}),
#    2877         **kwargs,
#    2878     )
#
# File ~/Desktop/remeve_me/pythonProject1/.venv/lib/python3.9/site-packages/matplotlib/__init__.py:1473, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1470 @functools.wraps(func)
#    1471 def inner(ax, *args, data=None, **kwargs):
#    1472     if data is None:
# -> 1473         return func(
#    1474             ax,
#    1475             *map(sanitize_sequence, args),
#    1476             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1478     bound = new_sig.bind(ax, *args, **kwargs)
#    1479     auto_label = (bound.arguments.get(label_namer)
#    1480                   or bound.kwargs.get(label_namer))
#
# File ~/Desktop/remeve_me/pythonProject1/.venv/lib/python3.9/site-packages/matplotlib/axes/_axes.py:2583, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2580 args = zip(left, bottom, width, height, color, edgecolor, linewidth,
#    2581            hatch, patch_labels)
#    2582 for l, b, w, h, c, e, lw, htch, lbl in args:
# -> 2583     r = mpatches.Rectangle(
#    2584         xy=(l, b), width=w, height=h,
#    2585         facecolor=c,
#    2586         edgecolor=e,
#    2587         linewidth=lw,
#    2588         label=lbl,
#    2589         hatch=htch,
#    2590         )
#    2591     r._internal_update(kwargs)
#    2592     r.get_path()._interpolation_steps = 100
#
# File ~/Desktop/remeve_me/pythonProject1/.venv/lib/python3.9/site-packages/matplotlib/patches.py:762, in Rectangle.__init__(self, xy, width, height, angle, rotation_point, **kwargs)
#     738 @_docstring.dedent_interpd
#     739 def __init__(self, xy, width, height, *,
#     740              angle=0.0, rotation_point='xy', **kwargs):
#     741     """
#     742     Parameters
#     743     ----------
#    (...)
#     760         %(Patch:kwdoc)s
#     761     """
# --> 762     super().__init__(**kwargs)
#     763     self._x0 = xy[0]
#     764     self._y0 = xy[1]
#
# File ~/Desktop/remeve_me/pythonProject1/.venv/lib/python3.9/site-packages/matplotlib/patches.py:91, in Patch.__init__(self, edgecolor, facecolor, color, linewidth, linestyle, antialiased, hatch, fill, capstyle, joinstyle, **kwargs)
#      88 self._dash_pattern = (0, None)  # offset, dash (scaled by linewidth)
#      90 self.set_linestyle(linestyle)
# ---> 91 self.set_linewidth(linewidth)
#      92 self.set_antialiased(antialiased)
#      93 self.set_hatch(hatch)
#
# File ~/Desktop/remeve_me/pythonProject1/.venv/lib/python3.9/site-packages/matplotlib/patches.py:438, in Patch.set_linewidth(self, w)
#     436 if w is None:
#     437     w = mpl.rcParams['patch.linewidth']
# --> 438 self._linewidth = float(w)
#     439 self._dash_pattern = mlines._scale_dashes(
#     440     *self._unscaled_dash_pattern, w)
#     441 self.stale = True
#
# TypeError: only length-1 arrays can be converted to Python scalars
